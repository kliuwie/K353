# %%
import os, pandas as pd, numpy as np

# %%
os.listdir()
# Out:
# ['cpsa2017.xlsx',
#  'kaggle_income.csv',
#  'Apartment-List-Rent-Data-State_2018-4.csv',
#  'kaggle_income1.csv',
#  '.ipynb_checkpoints',
#  'K353 Group Project.ipynb']

# %%
kag_inc = pd.read_csv('kaggle_income.csv')
kag_inc_1 = pd.read_csv('kaggle_income1.csv')

# %%
kag_inc
# Out:
#               Row Labels Average of Mean Average of Median
# 0                Alabama          53,613            62,771
# 1                 Alaska          77,670           108,912
# 2                Arizona          62,578            79,374
# 3               Arkansas          52,060            52,382
# 4             California          78,127           100,582
# 5               Colorado          73,323            99,513
# 6            Connecticut          89,227           120,557
# 7               Delaware          70,142            87,086
# 8   District of Columbia          90,668            93,760
# 9                Florida          60,888            75,204
# 10               Georgia          60,354            71,669
# 11                Hawaii          77,860            95,679
# 12                 Idaho          56,211            81,456
# 13              Illinois          69,067            86,771
# 14               Indiana          59,154            83,274
# ...

# %%
cpsa = pd.read_csv('Apartment-List-Rent-Data-State_2018-4.csv')

# %%
cpsa
# Out:
#           Location Location_Type Bedroom_Size  Price_2014_01  Price_2014_02  \
# 0          Alabama         State       Studio            573            573
# 1          Alabama         State          1br            624            624
# 2          Alabama         State          2br            758            758
# 3          Alabama         State          3br           1013           1013
# 4          Alabama         State          4br           1178           1178
# 5           Alaska         State       Studio            841            846
# 6           Alaska         State          1br            961            967
# 7           Alaska         State          2br           1230           1237
# 8           Alaska         State          3br           1738           1748
# 9           Alaska         State          4br           2086           2098
# 10         Arizona         State       Studio            600            603
# ...
