# %%
import os, pandas as pd, numpy as np

# %%
os.listdir()
# Out:
# ['cpsa2017.xlsx',
#  'avocado.csv',
#  'kaggle_income.csv',
#  'Apartment-List-Rent-Data-State_2018-4.csv',
#  'kaggle_income1.csv',
#  '.ipynb_checkpoints',
#  'K353 Group Project.ipynb']

# %%
guac  = pd.read_csv('avocado.csv')

# %%
guac.keys()
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %% [markdown]
# # Topic: To predict demand or price for different size of avocados in specific region based on its type.

# %% [markdown]
# Data is taken from : https://www.kaggle.com/neuromusic/avocado-prices/home

# %%
guac.shape
# Out:
# (18249, 14)

# %% [markdown]
# There are 18249 rows and 14 columns. Columns information are below:
#
# Unnamed: IDs (Categorical : Nominal)
#
# Date (Categorical: Ordinal)
#
# AveragePrice (Numerical: Discrete)
#
# Total Volume (Numerical: Discrete)
#
# 4046: small Hass (Numerical: Discrete)
#
# 4225: large Hass (Numerical: Discrete)
#
# 4770: extra large Hass(Numerical: Discrete)
#
# Total Bags (Numerical: Discrete)
#
# Small Bags (Numerical: Discrete)
#
# Large Bags (Numerical: Discrete)
#
# XLarge Bags (Numerical: Discrete)
#
# type (Categorical: Nominal)
#
# year (Categorical: Ordinal)
#
# region (Categorical: Nominal)

# %%
guac.describe(include='all')
# Out:
#           Unnamed: 0        Date  AveragePrice  Total Volume          4046  \
# count   18249.000000       18249  18249.000000  1.824900e+04  1.824900e+04
# unique           NaN         169           NaN           NaN           NaN
# top              NaN  2016-06-05           NaN           NaN           NaN
# freq             NaN         108           NaN           NaN           NaN
# mean       24.232232         NaN      1.405978  8.506440e+05  2.930084e+05
# std        15.481045         NaN      0.402677  3.453545e+06  1.264989e+06
# min         0.000000         NaN      0.440000  8.456000e+01  0.000000e+00
# 25%        10.000000         NaN      1.100000  1.083858e+04  8.540700e+02
# 50%        24.000000         NaN      1.370000  1.073768e+05  8.645300e+03
# 75%        38.000000         NaN      1.660000  4.329623e+05  1.110202e+05
# max        52.000000         NaN      3.250000  6.250565e+07  2.274362e+07
#
#                 4225          4770    Total Bags    Small Bags    Large Bags  \
# count   1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    2.951546e+05  2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04
# std     1.204120e+06  1.074641e+05  9.862424e+05  7.461785e+05  2.439660e+05
# min     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%     3.008780e+03  0.000000e+00  5.088640e+03  2.849420e+03  1.274700e+02
# 50%     2.906102e+04  1.849900e+02  3.974383e+04  2.636282e+04  2.647710e+03
# 75%     1.502069e+05  6.243420e+03  1.107834e+05  8.333767e+04  2.202925e+04
# max     2.047057e+07  2.546439e+06  1.937313e+07  1.338459e+07  5.719097e+06
#
#           XLarge Bags          type          year   region
# count    18249.000000         18249  18249.000000    18249
# unique            NaN             2           NaN       54
# top               NaN  conventional           NaN  Orlando
# freq              NaN          9126           NaN      338
# mean      3106.426507           NaN   2016.147899      NaN
# std      17692.894652           NaN      0.939938      NaN
# min          0.000000           NaN   2015.000000      NaN
# 25%          0.000000           NaN   2015.000000      NaN
# 50%          0.000000           NaN   2016.000000      NaN
# 75%        132.500000           NaN   2017.000000      NaN
# max     551693.650000           NaN   2018.000000      NaN

# %% [markdown]
# On initial run, there seems to be no missing value in the data.

# %%
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
# %matplotlib inline

# %%
scatter_matrix(guac,diagonal='kde',figsize=[20,20])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0e3626d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0e5e3860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0e47a710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0e1c1d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0e184080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0e1840b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0e1476a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0e1679b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0e110dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0e0c3470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0e0e9b00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0e09b1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0e043860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0e06bef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0e01c5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0dfc4c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0dff6320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0df9b9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0df4d080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0df74710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0df1eda0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0dece470>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0def6b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0dea61d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0de4c860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0de75ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0de265c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0ddcdc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0dd81320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0dda69b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0dd56080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0dcff710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0dd29da0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0dcd8470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0dcfeb00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0dcb31d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0dc59860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0dc00ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0dc335c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0dbdbc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0db8b320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0dbb29b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0db64080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0db0c710>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0db36da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0dae7470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0da8fb00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0da411d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0da67860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0da10ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d9c25c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d9ecc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d99d320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d9459b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d979080>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d920710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d8c6da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d8f9470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d8a0b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d8531d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d87b860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d825ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa20c71b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d7f06d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d799d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d74c438>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d771ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d724198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d6cf828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d6f5eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d6a6588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d64ec18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d6022e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d629978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d5d8048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d5856d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d5abd68>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d55c438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d505ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d537198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d4de828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d489eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d4b9588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d461c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d4142e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d43c978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d3ee048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d3956d8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d3bcd68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d36f438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d317ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d2cb198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d2f2828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d29beb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d24b588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d273c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d2272e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d1cd978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d17f048>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d1aa6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d150d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d101438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d12bac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d0dc198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d084828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d0adeb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d05e588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d006c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0d03a2e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0cfe1978>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0cf93048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0cfbc6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0cf62d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0cf13438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0cf3cac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0ceef198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0ce97828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0cebdeb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0ce70588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0ce18c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ffa0cdc92e8>]],
#       dtype=object)

# %%
guac.corr()
# Out:
#               Unnamed: 0  AveragePrice  Total Volume      4046      4225  \
# Unnamed: 0      1.000000     -0.133008      0.014035  0.017628  0.019829
# AveragePrice   -0.133008      1.000000     -0.192752 -0.208317 -0.172928
# Total Volume    0.014035     -0.192752      1.000000  0.977863  0.974181
# 4046            0.017628     -0.208317      0.977863  1.000000  0.926110
# 4225            0.019829     -0.172928      0.974181  0.926110  1.000000
# 4770            0.041752     -0.179446      0.872202  0.833389  0.887855
# Total Bags     -0.002219     -0.177088      0.963047  0.920057  0.905787
# Small Bags      0.000347     -0.174730      0.967238  0.925280  0.916031
# Large Bags     -0.009196     -0.172940      0.880640  0.838645  0.810015
# XLarge Bags    -0.011546     -0.117592      0.747157  0.699377  0.688809
# year           -0.171667      0.093197      0.017193  0.003353 -0.009559
#
#                   4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Unnamed: 0    0.041752   -0.002219    0.000347   -0.009196    -0.011546
# AveragePrice -0.179446   -0.177088   -0.174730   -0.172940    -0.117592
# Total Volume  0.872202    0.963047    0.967238    0.880640     0.747157
# 4046          0.833389    0.920057    0.925280    0.838645     0.699377
# 4225          0.887855    0.905787    0.916031    0.810015     0.688809
# 4770          1.000000    0.792314    0.802733    0.698471     0.679861
# Total Bags    0.792314    1.000000    0.994335    0.943009     0.804233
# Small Bags    0.802733    0.994335    1.000000    0.902589     0.806845
# Large Bags    0.698471    0.943009    0.902589    1.000000     0.710858
# XLarge Bags   0.679861    0.804233    0.806845    0.710858     1.000000
# year         -0.036531    0.071552    0.063915    0.087891     0.081033
#
#                   year
# Unnamed: 0   -0.171667
# AveragePrice  0.093197
# Total Volume  0.017193
# 4046          0.003353
# 4225         -0.009559
# 4770         -0.036531
# Total Bags    0.071552
# Small Bags    0.063915
# Large Bags    0.087891
# XLarge Bags   0.081033
# year          1.000000
